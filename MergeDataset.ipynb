# %%
# !wget http://www.aueb.gr/users/ion/data/enron-spam/preprocessed/enron1.tar.gz
# !wget http://www.aueb.gr/users/ion/data/enron-spam/preprocessed/enron2.tar.gz
# !wget http://www.aueb.gr/users/ion/data/enron-spam/preprocessed/enron3.tar.gz
# !wget http://www.aueb.gr/users/ion/data/enron-spam/preprocessed/enron4.tar.gz
# !wget http://www.aueb.gr/users/ion/data/enron-spam/preprocessed/enron5.tar.gz
# !wget http://www.aueb.gr/users/ion/data/enron-spam/preprocessed/enron6.tar.gz
# Out:
# --2021-04-21 23:49:29--  http://www.aueb.gr/users/ion/data/enron-spam/preprocessed/enron1.tar.gz
# Resolving www.aueb.gr (www.aueb.gr)... 195.251.255.156
# Connecting to www.aueb.gr (www.aueb.gr)|195.251.255.156|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: http://www2.aueb.gr/users/ion/data/enron-spam/preprocessed/enron1.tar.gz [following]
# --2021-04-21 23:49:30--  http://www2.aueb.gr/users/ion/data/enron-spam/preprocessed/enron1.tar.gz
# Resolving www2.aueb.gr (www2.aueb.gr)... 195.251.255.138
# Connecting to www2.aueb.gr (www2.aueb.gr)|195.251.255.138|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1802573 (1.7M) [application/x-gzip]
# Saving to: ‘enron1.tar.gz’
#
# enron1.tar.gz       100%[===================>]   1.72M   289KB/s    in 7.7s
#
# 2021-04-21 23:49:39 (230 KB/s) - ‘enron1.tar.gz’ saved [1802573/1802573]
#
# ...

# %%
# !tar zxvf enron1.tar.gz
# !tar zxvf enron2.tar.gz
# !tar zxvf enron3.tar.gz
# !tar zxvf enron4.tar.gz
# !tar zxvf enron5.tar.gz
# !tar zxvf enron6.tar.gz
# Out:
# 串流輸出內容已截斷至最後 5000 行。
# enron6/ham/4062.2001-07-30.lokay.ham.txt
# enron6/ham/4068.2001-07-30.lokay.ham.txt
# enron6/ham/4072.2001-07-30.lokay.ham.txt
# enron6/ham/4073.2001-07-31.lokay.ham.txt
# enron6/ham/4079.2001-07-31.lokay.ham.txt
# enron6/ham/4081.2001-08-01.lokay.ham.txt
# enron6/ham/4084.2001-08-01.lokay.ham.txt
# enron6/ham/4089.2001-08-01.lokay.ham.txt
# enron6/ham/4096.2001-08-01.lokay.ham.txt
# enron6/ham/4100.2001-08-01.lokay.ham.txt
# enron6/ham/4102.2001-08-02.lokay.ham.txt
# enron6/ham/4104.2001-08-02.lokay.ham.txt
# enron6/ham/4106.2001-08-02.lokay.ham.txt
# enron6/ham/4108.2001-08-02.lokay.ham.txt
# enron6/ham/4110.2001-08-02.lokay.ham.txt
# enron6/ham/4115.2001-08-02.lokay.ham.txt
# enron6/ham/4118.2001-08-02.lokay.ham.txt
# enron6/ham/4121.2001-08-03.lokay.ham.txt
# enron6/ham/4125.2001-08-03.lokay.ham.txt
# enron6/ham/4128.2001-08-03.lokay.ham.txt
# enron6/ham/4133.2001-08-03.lokay.ham.txt
# enron6/ham/4139.2001-08-03.lokay.ham.txt
# ...

# %%
import os
import glob
import numpy as np
import email
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
path = '/content/enron*/'
ham_paths = glob.glob(path+'ham/*')
spam_paths = glob.glob(path+'spam/*')

# %%
def get_email_content(email_path):
  file = open(email_path,encoding='latin1')
  try:
        msg = email.message_from_file(file)
        for part in msg.walk():
            if part.get_content_type() == 'text/plain':
                return part.get_payload() # prints the raw text
  except Exception as e:
        print(e)
def get_email_content_bulk(email_paths):
    email_contents = [get_email_content(o) for o in email_paths]
    return email_contents

# %%
ham_sample=np.array(train_test_split(ham_paths))
ham_train=np.array(ham_sample[0])
ham_test=np.array(ham_sample[1])
ham_train.shape, ham_test.shape
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   """Entry point for launching an IPython kernel.
# ((12408,), (4137,))

# %%
spam_sample=np.array(train_test_split(spam_paths))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   """Entry point for launching an IPython kernel.

# %%
spam_train=np.array(spam_sample[0])
spam_test=np.array(spam_sample[1])
spam_train.shape, spam_test.shape
# Out:
# ((12878,), (4293,))

# %%
ham_train_label = [0]*ham_train.shape[0]
spam_train_label = [1]*spam_train.shape[0]
x_train = np.concatenate((ham_train,spam_train))
y_train = np.concatenate((ham_train_label,spam_train_label))

# %%
ham_test_label = [0]*ham_test.shape[0]
spam_test_label = [1]*spam_test.shape[0]
x_test = np.concatenate((ham_test,spam_test))
y_test = np.concatenate((ham_test_label,spam_test_label))

# %%
train_shuffle_index = np.random.permutation(np.arange(0,x_train.shape[0]))
test_shuffle_index = np.random.permutation(np.arange(0,x_test.shape[0]))

# %%
x_train = x_train[train_shuffle_index]
y_train = y_train[train_shuffle_index]

# %%
x_test = x_test[test_shuffle_index]
y_test = y_test[test_shuffle_index]

# %%
eron1=np.concatenate((x_train,x_test))
eron2=np.concatenate((y_train,y_test))
pd.DataFrame(
    {'label': eron2,
     'content': get_email_content_bulk(eron1)}).to_csv('eron_data.csv', index=False)

# %%
x=pd.read_csv('/content/eron_data.csv')
x.describe()
x.dropna()
# Out:
#        label                                            content
# 0          0  shanbhogue , vasant has suggested reviewers an...
# 1          1  full side , there suggest , might close , base...
# 2          1  dear applicant , after further review upon rec...
# 3          1  get the finest rolex watch replica !\nwe only ...
# 4          1  heya !\nhas your cum ever dribbled and you wis...
# ...      ...                                                ...
# 33711      1  ozone athenian asperity lineal inculpable are ...
# 33712      1  re - finance now , even with bad - credit !\n*...
# 33713      1  hi my name is ms bower , i am customer support...
# 33714      1  the money control system\nwould your lifestyle...
# 33715      0  a position has recently become available in th...
#
# [33344 rows x 2 columns]

# %%
ham1=[]
spam1=[]
for o in x['label']:
  if o==0:
    ham1.append(1)
  elif o==1:
    spam1.append(2)
differenceN1=int(int(len(ham1)*0.4538)/(1-0.4538))
differenceN1=len(spam1)-differenceN1

# %%
indexNames = x[x['label'] == 1].index
for i in range(differenceN1):
  x.drop(indexNames[i] , inplace=True)

# %%
x
# Out:
#        label                                            content
# 0          0  shanbhogue , vasant has suggested reviewers an...
# 5          0  daren\nsee below - bad news - mobil beaumont v...
# 6          0  risk - management optimization model ; 3 . enr...
# 8          0  brooklyn -\nattached you ' ll find your spread...
# 10         0  this is a reminder that today ( thursday , 4 /...
# ...      ...                                                ...
# 33711      1  ozone athenian asperity lineal inculpable are ...
# 33712      1  re - finance now , even with bad - credit !\n*...
# 33713      1  hi my name is ms bower , i am customer support...
# 33714      1  the money control system\nwould your lifestyle...
# 33715      0  a position has recently become available in th...
#
# [30290 rows x 2 columns]

# %%
x.loc[x['label']==1]
# Out:
#        label                                            content
# 6671       1  we have the price that fits your budget .\nnow...
# 6672       1  usual island carry when put , dry . white shal...
# 6673       1  your membership community & commentary ( augus...
# 6675       1  hello ,\nsave your health your money\nget all ...
# 6679       1  it is easier . select our chemist - site that ...
# ...      ...                                                ...
# 33710      1  hello , how would you like to spend iess on yo...
# 33711      1  ozone athenian asperity lineal inculpable are ...
# 33712      1  re - finance now , even with bad - credit !\n*...
# 33713      1  hi my name is ms bower , i am customer support...
# 33714      1  the money control system\nwould your lifestyle...
#
# [13745 rows x 2 columns]

# %%
x.to_csv('Mergedata.csv',index=False)
